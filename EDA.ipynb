# %% [markdown]
# <a href="https://colab.research.google.com/github/thykers/Fish_Identification/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download Data

# %% [markdown]
# Download the fish dataset using the Kaggle API

# %%
import matplotlib.pyplot as plt
import zipfile

# %%
# !kaggle datasets download crowww/a-large-scale-fish-dataset
# Out:
# ...
# 100% 3.24G/3.24G [00:24<00:00, 145MB/s]
# 100% 3.24G/3.24G [00:24<00:00, 143MB/s]

# %% [markdown]
# Create the data directory and extract the data from the zipfile

# %%
# !mkdir data

# %%
with zipfile.ZipFile('./a-large-scale-fish-dataset.zip', 'r') as zip_ref:
  zip_ref.extractall('./data/')

# %%
path_to_data = '/content/data/Fish_Dataset/Fish_Dataset/'

# %%
# An example
example_path = os.path.join(path_to_data, 'Black Sea Sprat/Black Sea Sprat/00001.png')
#image = plt.imread('/content/data/Fish_Dataset/Fish_Dataset/Black Sea Sprat/Black Sea Sprat/00001.png')
image = plt.imread(example_path)
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')
plt.show()
